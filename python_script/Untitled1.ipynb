# %%
""" ZAETTA Paul (code for December, 2016)

    This script transforms the Wind Power Generation data set (.txt) into csv format. 
    
    -----------------------------------------------------------------------------------------------
    Output: 
    
    Time(Hour-Minute-Seconde), Speed(m/s), Direction(°), Energy(kWh), Date(Day-Month-Year)
    -----------------------------------------------------------------------------------------------
    
    WARNING: This script is applied to the month of December (we print only the first day of December, 2016)

"""

import os

os.chdir("/Users/paulzaetta/Desktop/Master Thesis/Data/data_all_format_txt")

#mon_fichier = open("January, 2016.txt", "r")
#mon_fichier = open("February, 2016.txt", "r")
#mon_fichier = open("March, 2016.txt", "r")
#mon_fichier = open("April, 2016.txt", "r")
#mon_fichier = open("May, 2016.txt", "r")
#mon_fichier = open("June, 2016.txt", "r")
#mon_fichier = open("July, 2016.txt", "r")
#mon_fichier = open("August, 2016.txt", "r")
#mon_fichier = open("September, 2016.txt", "r")
#mon_fichier = open("October, 2016.txt", "r")
#mon_fichier = open("November, 2016.txt", "r")
mon_fichier = open("December, 2016.txt", "r")
         
contenu = mon_fichier.read()

# %%
contenu = contenu.replace('DateSpeed (m/s)Direction (º)Energy (kWh)','')
contenu = contenu.replace('/', '-')
contenu = contenu.replace('.','')
contenu = contenu.replace(',','.')
contenu = contenu.replace(':','-')
contenu = contenu[11:]

contenu = contenu.replace(' ', '\n')

# %%
i = 0
y = 0
length = len(contenu)

while y < length:
    if i == 8:
        contenu = contenu[0:y+8]+","+contenu[y+8:length]
        length = len(contenu)
    if (i == 10 and contenu[y+9] != "-" and contenu[y+10] == "." and contenu[y+17] == "."):
        contenu = contenu[0:y+13]+","+contenu[y+13:length]
        length = len(contenu)
        contenu = contenu[0:y+17]+","+contenu[y+17:length]
        length = len(contenu)
        contenu = contenu[0:y+22]+","+contenu[y+22:length]
        length = len(contenu)
        #contenu = contenu[0:y+33]+","+contenu[y+33:length]
        #length = len(contenu)
        i = -1
        y += 34
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+10] == "." and contenu[y+18] == "."):
        contenu = contenu[0:y+13]+","+contenu[y+13:length]
        length = len(contenu)
        contenu = contenu[0:y+17]+","+contenu[y+17:length]
        length = len(contenu)
        contenu = contenu[0:y+23]+","+contenu[y+23:length]
        length = len(contenu)
        #contenu = contenu[0:y+34]+","+contenu[y+34:length]
        #length = len(contenu)
        i = -1
        y += 35
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+10] == "." and contenu[y+19] == "."):
        contenu = contenu[0:y+13]+","+contenu[y+13:length]
        length = len(contenu)
        contenu = contenu[0:y+17]+","+contenu[y+17:length]
        length = len(contenu)
        contenu = contenu[0:y+24]+","+contenu[y+24:length]
        length = len(contenu)
        #contenu = contenu[0:y+35]+","+contenu[y+35:length]
        #length = len(contenu)
        i = -1
        y += 36
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+10] == "." and contenu[y+16] == "."):
        contenu = contenu[0:y+13]+","+contenu[y+13:length]
        length = len(contenu)
        contenu = contenu[0:y+17]+",0"+contenu[y+17:length]
        length = len(contenu)
        contenu = contenu[0:y+22]+","+contenu[y+22:length]
        length = len(contenu)
        #contenu = contenu[0:y+33]+","+contenu[y+33:length]
        #length = len(contenu)
        i = -1
        y += 34
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+10] == "." and contenu[y+20] == "."):
        contenu = contenu[0:y+13]+","+contenu[y+13:length]
        length = len(contenu)
        contenu = contenu[0:y+17]+","+contenu[y+17:length]
        length = len(contenu)
        contenu = contenu[0:y+25]+","+contenu[y+25:length]
        length = len(contenu)
        #contenu = contenu[0:y+36]+","+contenu[y+36:length]
        #length = len(contenu)
        i = -1
        y += 37
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+11] == "." and contenu[y+18] == "."):
        contenu = contenu[0:y+14]+","+contenu[y+14:length]
        length = len(contenu)
        contenu = contenu[0:y+18]+","+contenu[y+18:length]
        length = len(contenu)
        contenu = contenu[0:y+23]+","+contenu[y+23:length]
        length = len(contenu)
        #contenu = contenu[0:y+34]+","+contenu[y+34:length]
        #length = len(contenu)
        i = -1
        y += 35
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+11] == "." and contenu[y+19] == "."):
        contenu = contenu[0:y+14]+","+contenu[y+14:length]
        length = len(contenu)
        contenu = contenu[0:y+18]+","+contenu[y+18:length]
        length = len(contenu)
        contenu = contenu[0:y+24]+","+contenu[y+24:length]
        length = len(contenu)
        #contenu = contenu[0:y+35]+","+contenu[y+35:length]
        #length = len(contenu)
        i = -1
        y += 36
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+11] == "." and contenu[y+20] == "."):
        contenu = contenu[0:y+14]+","+contenu[y+14:length]
        length = len(contenu)
        contenu = contenu[0:y+18]+","+contenu[y+18:length]
        length = len(contenu)
        contenu = contenu[0:y+25]+","+contenu[y+25:length]
        length = len(contenu)
        #contenu = contenu[0:y+36]+","+contenu[y+36:length]
        #length = len(contenu)
        i = -1
        y += 37
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+11] == "." and contenu[y+21] == "."):
        contenu = contenu[0:y+14]+","+contenu[y+14:length]
        length = len(contenu)
        contenu = contenu[0:y+18]+","+contenu[y+18:length]
        length = len(contenu)
        contenu = contenu[0:y+26]+","+contenu[y+26:length]
        length = len(contenu)
        #contenu = contenu[0:y+37]+","+contenu[y+37:length]
        #length = len(contenu)
        i = -1
        y += 38
    elif (i == 10 and contenu[y+9] != "-" and contenu[y+11] == "." and contenu[y+17] == "."):
        contenu = contenu[0:y+14]+","+contenu[y+14:length]
        length = len(contenu)
        contenu = contenu[0:y+18]+",0"+contenu[y+18:length]
        length = len(contenu)
        contenu = contenu[0:y+23]+","+contenu[y+23:length]
        length = len(contenu)
        #contenu = contenu[0:y+34]+","+contenu[y+34:length]
        #length = len(contenu)
        i = -1
        y += 35
    elif (i == 10 and contenu[y+9] == "-"):
        contenu = contenu[0:y+10]+","+contenu[y+10:length]
        length = len(contenu)
        contenu = contenu[0:y+12]+","+contenu[y+12:length]
        length = len(contenu)
        contenu = contenu[0:y+14]+","+contenu[y+14:length]
        length = len(contenu)
        #contenu = contenu[0:y+25]+","+contenu[y+25:length]
        #length = len(contenu)
        i = -1  
        y += 26
    i += 1
    
print(contenu[0:5039])
# Out:
# 00-10-00,8.50,104,727.40,01-12-2016
# 00-20-00,9.08,108,738.79,01-12-2016
# 00-30-00,9.13,107,695.80,01-12-2016
# 00-40-00,8.99,112,604.60,01-12-2016
# 00-50-00,9.00,113,571.46,01-12-2016
# 01-00-00,8.84,108,581.68,01-12-2016
# 01-10-00,8.39,108,605.26,01-12-2016
# 01-20-00,8.35,115,613.69,01-12-2016
# 01-30-00,8.54,121,604.86,01-12-2016
# 01-40-00,8.94,125,608.57,01-12-2016
# 01-50-00,9.73,126,688.19,01-12-2016
# 02-00-00,9.45,125,697.46,01-12-2016
# 02-10-00,9.59,126,740.25,01-12-2016
# 02-20-00,9.59,126,739.70,01-12-2016
# 02-30-00,9.34,126,683.08,01-12-2016
# 02-40-00,9.19,125,683.89,01-12-2016
# 02-50-00,9.31,124,680.54,01-12-2016
# 03-00-00,9.90,127,763.67,01-12-2016
# 03-10-00,9.97,127,750.09,01-12-2016
# 03-20-00,9.24,125,547.53,01-12-2016
# 03-30-00,8.90,124,493.82,01-12-2016
# 03-40-00,8.46,122,540.99,01-12-2016
# 03-50-00,8.58,120,522.52,01-12-2016
# 04-00-00,8.67,123,462.13,01-12-2016
# 04-10-00,8.37,119,475.27,01-12-2016
# 04-20-00,8.12,116,539.68,01-12-2016
# ...

# %%
# Copy in my folder
f = open('/Users/paulzaetta/Desktop/Master Thesis/Data/csv/December_2016_csv', 'w')
f.write(contenu)
f.close()
mon_fichier.close()
